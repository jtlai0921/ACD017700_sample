# %% [markdown]
# ## 3.4 利用Q學習控制CartPole

# %%
# 套件的import
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
# 宣告動畫的繪圖函數
# 参考URL http://nbviewer.jupyter.org/github/patrickmineault
# /xcorr-notebooks/blob/master/Render%20OpenAI%20gym%20as%20GIF.ipynb
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display


def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)

    anim.save('movie_cartpole.mp4')  # 動畫檔案的命名與儲存
    display(display_animation(anim, default_mode='loop'))

# %%
# 常數的設定
ENV = 'CartPole-v0'  # 使用的課題名稱
NUM_DIZITIZED = 6  # 各狀態的離散值分割數
GAMMA = 0.99  # 時間折扣率
ETA = 0.5  # 學習係數
MAX_STEPS = 200  # 單回合的step數
NUM_EPISODES = 1000  # 最大回合數

# %%
class Agent:
    '''這是CartPole的智能體類別、代表的是立有棒子的推車'''

    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)  # 為了讓代理器決定動作而建置頭腦

    def update_Q_function(self, observation, action, reward, observation_next):
        '''Q函數的更新'''
        self.brain.update_Q_table(
            observation, action, reward, observation_next)

    def get_action(self, observation, step):
        '''決定動作'''
        action = self.brain.decide_action(observation, step)
        return action

# %%
class Brain:
    '''智能體的腦袋類別，會於此類別執行Q學習'''

    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # 取得CartPole的動作（向右或向左）的2

        # 建立Q table。列數為狀態轉換成分割數^（4個變數)的離散值、欄數為動作數量
        self.q_table = np.random.uniform(low=0, high=1, size=(
            NUM_DIZITIZED**num_states, num_actions))


    def bins(self, clip_min, clip_max, num):
        '''計算觀測所得的狀態（連續值)轉換成離散值的臨界值'''
        return np.linspace(clip_min, clip_max, num + 1)[1:-1]

    def digitize_state(self, observation):
        '''將觀測所得的observation狀態轉換成離散值'''
        cart_pos, cart_v, pole_angle, pole_v = observation
        digitized = [
            np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIZITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIZITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIZITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIZITIZED))
        ]
        return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)])

    def update_Q_table(self, observation, action, reward, observation_next):
        '''以Q學習更新Q table'''
        state = self.digitize_state(observation)  # 將狀態轉換成離散值
        state_next = self.digitize_state(observation_next)  # 將下一個狀態轉換成離散值
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + \
            ETA * (reward + GAMMA * Max_Q_next - self.q_table[state, action])

    def decide_action(self, observation, episode):
        '''以ε-greedy法篩減動作，直到最後只採行最佳的動作'''
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)  # 隨機傳回0,1的動作
        return action

# %%
class Environment:
    '''這是執行CartPole的環境類別'''

    def __init__(self):
        self.env = gym.make(ENV)  # 設定要執行的課題
        num_states = self.env.observation_space.shape[0]  # 取得課題的狀態數4
        num_actions = self.env.action_space.n  # 取得CartPole的動作（向右或向左）的2
        self.agent = Agent(num_states, num_actions)  # 於環境建立採行動作的Agent

    def run(self):
        '''執行'''
        complete_episodes = 0  # 連續執行195step以上的回合數
        is_episode_final = False  # 最終回合的旗標
        frames = []  # 儲存影像，供製作動畫之用的變數

        for episode in range(NUM_EPISODES):  # 重覆執行，直到設定的回合數為止
            observation = self.env.reset()  # 初始化環境

            for step in range(MAX_STEPS):  # 1回合的迴圈

                if is_episode_final is True:  # 於最終回合將各時刻的影像存入frames
                    frames.append(self.env.render(mode='rgb_array'))

                # 求出動作
                action = self.agent.get_action(observation, episode)

                # 執行動作a_t、算出s_{t+1}, r_{t+1}
                observation_next, _, done, _ = self.env.step(
                    action)  # 由於不會用到reward與info所以設定為_

                # 給予報酬
                if done:  # Step數超過200或棒子傾斜至一定角度時，done將為true
                    if step < 195:
                        reward = -1  # 中途棒子傾倒的話，將以報酬-1作為罰則
                        complete_episodes = 0  # 連續195step之後，重設回合數
                    else:
                        reward = 1  # 若棒子依然直立，給予報酬1
                        complete_episodes += 1  # 更新連續記錄
                else:
                    reward = 0  # 中途的報酬為0

                # 以step+1的狀態observation_next更新Q函數
                self.agent.update_Q_function(
                    observation, action, reward, observation_next)

                # 觀測的更新
                observation = observation_next

                # 結束時的處理
                if done:
                    print('{0} Episode: Finished after {1} time steps'.format(
                        episode, step + 1))
                    break

            if is_episode_final is True:  # 於最終回合儲存與繪製動畫
                display_frames_as_gif(frames)
                break

            if complete_episodes >= 10:  # 連續10回合成功的話
                print('連續10回合成功')
                is_episode_final = True  # 將下回合視為繪製動畫的最終回合

# %%
# main
cartpole_env = Environment()
cartpole_env.run()
# Out:
# 0 Episode: Finished after 10 time steps
# 1 Episode: Finished after 15 time steps
# 2 Episode: Finished after 14 time steps
# 3 Episode: Finished after 10 time steps
# 4 Episode: Finished after 15 time steps
# 5 Episode: Finished after 18 time steps
# 6 Episode: Finished after 9 time steps
# 7 Episode: Finished after 10 time steps
# 8 Episode: Finished after 14 time steps
# 9 Episode: Finished after 12 time steps
# 10 Episode: Finished after 9 time steps
# 11 Episode: Finished after 19 time steps
# 12 Episode: Finished after 14 time steps
# 13 Episode: Finished after 25 time steps
# 14 Episode: Finished after 12 time steps
# 15 Episode: Finished after 11 time steps
# 16 Episode: Finished after 53 time steps
# 17 Episode: Finished after 13 time steps
# 18 Episode: Finished after 42 time steps
# 19 Episode: Finished after 26 time steps
# 20 Episode: Finished after 26 time steps
# 21 Episode: Finished after 16 time steps
# 22 Episode: Finished after 16 time steps
# 23 Episode: Finished after 13 time steps
# 24 Episode: Finished after 13 time steps
# 25 Episode: Finished after 26 time steps
# 26 Episode: Finished after 34 time steps
# 27 Episode: Finished after 25 time steps
# 28 Episode: Finished after 22 time steps
# 29 Episode: Finished after 39 time steps
# 30 Episode: Finished after 120 time steps
# 31 Episode: Finished after 80 time steps
# 32 Episode: Finished after 64 time steps
# 33 Episode: Finished after 66 time steps
# 34 Episode: Finished after 40 time steps
# 35 Episode: Finished after 136 time steps
# 36 Episode: Finished after 35 time steps
# 37 Episode: Finished after 150 time steps
# 38 Episode: Finished after 63 time steps
# 39 Episode: Finished after 40 time steps
# 40 Episode: Finished after 104 time steps
# 41 Episode: Finished after 10 time steps
# 42 Episode: Finished after 25 time steps
# 43 Episode: Finished after 11 time steps
# 44 Episode: Finished after 9 time steps
# 45 Episode: Finished after 9 time steps
# 46 Episode: Finished after 40 time steps
# 47 Episode: Finished after 17 time steps
# 48 Episode: Finished after 11 time steps
# 49 Episode: Finished after 45 time steps
# 50 Episode: Finished after 43 time steps
# 51 Episode: Finished after 47 time steps
# 52 Episode: Finished after 40 time steps
# 53 Episode: Finished after 39 time steps
# 54 Episode: Finished after 68 time steps
# 55 Episode: Finished after 41 time steps
# 56 Episode: Finished after 105 time steps
# 57 Episode: Finished after 24 time steps
# 58 Episode: Finished after 33 time steps
# 59 Episode: Finished after 97 time steps
# 60 Episode: Finished after 142 time steps
# 61 Episode: Finished after 160 time steps
# 62 Episode: Finished after 35 time steps
# 63 Episode: Finished after 36 time steps
# 64 Episode: Finished after 29 time steps
# 65 Episode: Finished after 71 time steps
# 66 Episode: Finished after 75 time steps
# 67 Episode: Finished after 50 time steps
# 68 Episode: Finished after 77 time steps
# 69 Episode: Finished after 44 time steps
# 70 Episode: Finished after 79 time steps
# 71 Episode: Finished after 37 time steps
# 72 Episode: Finished after 76 time steps
# 73 Episode: Finished after 101 time steps
# 74 Episode: Finished after 29 time steps
# 75 Episode: Finished after 131 time steps
# 76 Episode: Finished after 56 time steps
# 77 Episode: Finished after 41 time steps
# 78 Episode: Finished after 31 time steps
# 79 Episode: Finished after 120 time steps
# 80 Episode: Finished after 90 time steps
# 81 Episode: Finished after 91 time steps
# 82 Episode: Finished after 200 time steps
# 83 Episode: Finished after 200 time steps
# 84 Episode: Finished after 83 time steps
# 85 Episode: Finished after 142 time steps
# 86 Episode: Finished after 200 time steps
# 87 Episode: Finished after 200 time steps
# 88 Episode: Finished after 106 time steps
# 89 Episode: Finished after 200 time steps
# 90 Episode: Finished after 155 time steps
# 91 Episode: Finished after 200 time steps
# 92 Episode: Finished after 200 time steps
# 93 Episode: Finished after 200 time steps
# 94 Episode: Finished after 95 time steps
# 95 Episode: Finished after 200 time steps
# 96 Episode: Finished after 200 time steps
# 97 Episode: Finished after 200 time steps
# 98 Episode: Finished after 107 time steps
# 99 Episode: Finished after 200 time steps
# 100 Episode: Finished after 200 time steps
# 101 Episode: Finished after 200 time steps
# 102 Episode: Finished after 105 time steps
# 103 Episode: Finished after 106 time steps
# 104 Episode: Finished after 200 time steps
# 105 Episode: Finished after 200 time steps
# 106 Episode: Finished after 119 time steps
# 107 Episode: Finished after 200 time steps
# 108 Episode: Finished after 200 time steps
# 109 Episode: Finished after 101 time steps
# 110 Episode: Finished after 200 time steps
# 111 Episode: Finished after 200 time steps
# 112 Episode: Finished after 200 time steps
# 113 Episode: Finished after 200 time steps
# 114 Episode: Finished after 127 time steps
# 115 Episode: Finished after 111 time steps
# 116 Episode: Finished after 200 time steps
# 117 Episode: Finished after 200 time steps
# 118 Episode: Finished after 200 time steps
# 119 Episode: Finished after 158 time steps
# 120 Episode: Finished after 117 time steps
# 121 Episode: Finished after 176 time steps
# 122 Episode: Finished after 200 time steps
# 123 Episode: Finished after 152 time steps
# 124 Episode: Finished after 186 time steps
# 125 Episode: Finished after 174 time steps
# 126 Episode: Finished after 137 time steps
# 127 Episode: Finished after 188 time steps
# 128 Episode: Finished after 200 time steps
# 129 Episode: Finished after 200 time steps
# 130 Episode: Finished after 109 time steps
# 131 Episode: Finished after 168 time steps
# 132 Episode: Finished after 200 time steps
# 133 Episode: Finished after 200 time steps
# 134 Episode: Finished after 200 time steps
# 135 Episode: Finished after 200 time steps
# 136 Episode: Finished after 200 time steps
# 137 Episode: Finished after 148 time steps
# 138 Episode: Finished after 128 time steps
# 139 Episode: Finished after 200 time steps
# 140 Episode: Finished after 163 time steps
# 141 Episode: Finished after 200 time steps
# 142 Episode: Finished after 200 time steps
# 143 Episode: Finished after 200 time steps
# 144 Episode: Finished after 200 time steps
# 145 Episode: Finished after 200 time steps
# 146 Episode: Finished after 200 time steps
# 147 Episode: Finished after 200 time steps
# 148 Episode: Finished after 200 time steps
# 149 Episode: Finished after 200 time steps
# 150 Episode: Finished after 129 time steps
# 151 Episode: Finished after 200 time steps
# 152 Episode: Finished after 200 time steps
# 153 Episode: Finished after 136 time steps
# 154 Episode: Finished after 159 time steps
# 155 Episode: Finished after 200 time steps
# 156 Episode: Finished after 200 time steps
# 157 Episode: Finished after 200 time steps
# 158 Episode: Finished after 200 time steps
# 159 Episode: Finished after 200 time steps
# 160 Episode: Finished after 200 time steps
# 161 Episode: Finished after 200 time steps
# 162 Episode: Finished after 155 time steps
# 163 Episode: Finished after 99 time steps
# 164 Episode: Finished after 153 time steps
# 165 Episode: Finished after 200 time steps
# 166 Episode: Finished after 129 time steps
# 167 Episode: Finished after 197 time steps
# 168 Episode: Finished after 200 time steps
# 169 Episode: Finished after 200 time steps
# 170 Episode: Finished after 118 time steps
# 171 Episode: Finished after 145 time steps
# 172 Episode: Finished after 103 time steps
# 173 Episode: Finished after 200 time steps
# 174 Episode: Finished after 200 time steps
# 175 Episode: Finished after 200 time steps
# 176 Episode: Finished after 200 time steps
# 177 Episode: Finished after 200 time steps
# 178 Episode: Finished after 200 time steps
# 179 Episode: Finished after 26 time steps
# 180 Episode: Finished after 192 time steps
# 181 Episode: Finished after 41 time steps
# 182 Episode: Finished after 173 time steps
# 183 Episode: Finished after 200 time steps
# 184 Episode: Finished after 200 time steps
# 185 Episode: Finished after 200 time steps
# 186 Episode: Finished after 50 time steps
# 187 Episode: Finished after 151 time steps
# 188 Episode: Finished after 75 time steps
# 189 Episode: Finished after 200 time steps
# 190 Episode: Finished after 175 time steps
# 191 Episode: Finished after 169 time steps
# 192 Episode: Finished after 200 time steps
# 193 Episode: Finished after 131 time steps
# 194 Episode: Finished after 200 time steps
# 195 Episode: Finished after 200 time steps
# 196 Episode: Finished after 200 time steps
# 197 Episode: Finished after 200 time steps
# 198 Episode: Finished after 144 time steps
# 199 Episode: Finished after 200 time steps
# 200 Episode: Finished after 200 time steps
# 201 Episode: Finished after 200 time steps
# 202 Episode: Finished after 200 time steps
# 203 Episode: Finished after 44 time steps
# 204 Episode: Finished after 200 time steps
# 205 Episode: Finished after 87 time steps
# 206 Episode: Finished after 200 time steps
# 207 Episode: Finished after 14 time steps
# 208 Episode: Finished after 76 time steps
# 209 Episode: Finished after 40 time steps
# 210 Episode: Finished after 76 time steps
# 211 Episode: Finished after 175 time steps
# 212 Episode: Finished after 48 time steps
# 213 Episode: Finished after 90 time steps
# 214 Episode: Finished after 133 time steps
# 215 Episode: Finished after 18 time steps
# 216 Episode: Finished after 200 time steps
# 217 Episode: Finished after 200 time steps
# 218 Episode: Finished after 200 time steps
# 219 Episode: Finished after 200 time steps
# 220 Episode: Finished after 200 time steps
# 221 Episode: Finished after 200 time steps
# 222 Episode: Finished after 200 time steps
# 223 Episode: Finished after 162 time steps
# 224 Episode: Finished after 200 time steps
# 225 Episode: Finished after 200 time steps
# 226 Episode: Finished after 200 time steps
# 227 Episode: Finished after 200 time steps
# 228 Episode: Finished after 200 time steps
# 229 Episode: Finished after 200 time steps
# 230 Episode: Finished after 200 time steps
# 231 Episode: Finished after 200 time steps
# 232 Episode: Finished after 200 time steps
# 233 Episode: Finished after 200 time steps
# 連續10回合成功
# 234 Episode: Finished after 200 time steps
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgSYIUYLYWRNDSMYBV">
#     <br>
#     <input id="_anim_sliderSYIUYLYWRNDSMYBV" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animSYIUYLYWRNDSMYBV.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animSYIUYLYWRNDSMYBV.slower()">&#8211;</button>
#     <button onclick="animSYIUYLYWRNDSMYBV.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSYIUYLYWRNDSMYBV.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSYIUYLYWRNDSMYBV.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSYIUYLYWRNDSMYBV.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animSYIUYLYWRNDSMYBV.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSYIUYLYWRNDSMYBV.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSYIUYLYWRNDSMYBV.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSYIUYLYWRNDSMYBV.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectSYIUYLYWRNDSMYBV" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgSYIUYLYWRNDSMYBV";
#     var slider_id = "_anim_sliderSYIUYLYWRNDSMYBV";
#     var loop_select_id = "_anim_loop_selectSYIUYLYWRNDSMYBV";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6
